# %%
AI is a broad field which mimics human intelligence
it is a machine which automates the human tasks.

# %%
# Types of AI:
# 1. Narrow AI
# 2. Broad AI
# 3. Gen AI
# 4. Agentic AI
# 5. Personal AI

# %%
1. Narrow AI
-> It is a machine which automates the human tasks.
